# %% [raw]
# #学习使用github的第一天#
#  创建自己的学习笔记daily_learning_notes
# 1按 Ctrl + S 保存
# 2按 Ctrl + K（神键！）
# 3弹出的 Commit 窗口：
# 4文件自动勾选
# 5提交消息写：2025-12-12 第一次成功同步
# 6点右上角绿色 Commit and Push
# 7弹窗点 Push
#
# 遇到的问题：推送被拒，合并错误
# 解决方法：
